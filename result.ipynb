# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import fileinput, glob, os
import datetime
import missingno as msno
import seaborn as sns

# %%
connections = pd.read_csv('transactions/download_bank_connections.csv')
connections.head()
# Out:
#    icij_sar_id       filer_org_name_id          filer_org_name  \
# 0         4132  standard-chartered-plc  Standard Chartered Plc
# 1         3181  standard-chartered-plc  Standard Chartered Plc
# 2         3181  standard-chartered-plc  Standard Chartered Plc
# 3         3181  standard-chartered-plc  Standard Chartered Plc
# 4         3181  standard-chartered-plc  Standard Chartered Plc
#
#                                          entity_b_id  \
# 0  habib-metropolitan-bank-limited-karachi-pakist...
# 1              standard-chartered-bank-dubai-uae-are
# 2        al-rostamani-international-exchange-uae-are
# 3  kuwait-turkish-participation-bank-inc-istanbul...
# 4      wall-street-exchange-center-llc-dubai-uae-are
#
#                                 entity_b      entity_b_country  \
# 0        Habib Metropolitan Bank Limited              Pakistan
# 1                Standard Chartered Bank  United Arab Emirates
# 2    Al Rostamani International Exchange  United Arab Emirates
# 3  Kuwait Turkish Participation Bank Inc                Turkey
# 4        Wall Street Exchange Center Llc  United Arab Emirates
#
#   entity_b_iso_code
# 0               PAK
# 1               ARE
# 2               ARE
# 3               TUR
# 4               ARE

# %%
mapp = pd.read_csv('transactions/download_transactions_map.csv',index_col=0)
mapp['begin_date'] = pd.to_datetime(mapp['begin_date'], format='%b %d, %Y')
mapp['end_date'] = pd.to_datetime(mapp['end_date'], format='%b %d, %Y')
mapp.head(16)
# Out:
#         icij_sar_id                 filer_org_name_id  \
# id
# 223254         3297  the-bank-of-new-york-mellon-corp
# 223255         3297  the-bank-of-new-york-mellon-corp
# 223258         2924  the-bank-of-new-york-mellon-corp
# 223259         2924  the-bank-of-new-york-mellon-corp
# 223260         2924  the-bank-of-new-york-mellon-corp
# 223261         2924  the-bank-of-new-york-mellon-corp
# 223262         2924  the-bank-of-new-york-mellon-corp
# 223263         2924  the-bank-of-new-york-mellon-corp
# 223264         2924  the-bank-of-new-york-mellon-corp
# 223265         2924  the-bank-of-new-york-mellon-corp
# 223266         2924  the-bank-of-new-york-mellon-corp
# 223267         2924  the-bank-of-new-york-mellon-corp
# 223268         2924  the-bank-of-new-york-mellon-corp
# 223269         2924  the-bank-of-new-york-mellon-corp
# 223270         2924  the-bank-of-new-york-mellon-corp
# 223271         2924  the-bank-of-new-york-mellon-corp
#
#                            filer_org_name begin_date   end_date  \
# id
# 223254  The Bank of New York Mellon Corp. 2015-03-25 2015-09-25
# 223255  The Bank of New York Mellon Corp. 2015-03-30 2015-09-25
# 223258  The Bank of New York Mellon Corp. 2012-07-05 2012-07-05
# 223259  The Bank of New York Mellon Corp. 2012-06-20 2012-06-20
# 223260  The Bank of New York Mellon Corp. 2012-05-31 2012-05-31
# 223261  The Bank of New York Mellon Corp. 2012-05-29 2012-05-29
# 223262  The Bank of New York Mellon Corp. 2012-05-29 2012-05-29
# 223263  Skandinaviska Enskilda Banken                   Sweden
# 223264  Skandinaviska Enskilda Banken                   Sweden
# 223265  Skandinaviska Enskilda Banken                   Sweden
# 223266  Skandinaviska Enskilda Banken                   Sweden
# 223267  Skandinaviska Enskilda Banken                   Sweden
# 223268  Skandinaviska Enskilda Banken                   Sweden
# 223269  Skandinaviska Enskilda Banken                   Sweden
# 223270  Skandinaviska Enskilda Banken                   Sweden
# 223271  Skandinaviska Enskilda Banken                   Sweden
#
#        beneficiary_iso  number_transactions  amount_transactions
# id
# 223254             GBR                 68.0         5.689852e+07
# 223255             GBR                118.0         1.162384e+08
# 223258             SWE                  NaN         5.000000e+03
# 223259             SWE                  NaN         9.990000e+03
# 223260             SWE                  NaN         1.200000e+04
# 223261             SWE                  NaN         8.803000e+01
# 223262             SWE                  NaN         1.300000e+04
# 223263             SWE                  NaN         6.990000e+03
# 223264             SWE                  NaN         8.000000e+03
# 223265             SWE                  NaN         6.990000e+03
# 223266             SWE                  NaN         7.090000e+03
# 223267             SWE                  NaN         1.300000e+04
# 223268             SWE                  NaN         4.000100e+02
# 223269             SWE                  NaN         7.290000e+03
# 223270             SWE                  NaN         7.290000e+03
# 223271             SWE                  NaN         7.090000e+03

# %%
#before importing data from btc-tx.csv I had to correct some rows in text editor and replace double quotes
#and missing/incorrect transaction amounts taken from blockchain.com according to hash id
parser = lambda date: datetime.datetime.strptime(date, '%Y-%m-%d')

btctx = pd.read_csv('btctx.csv', parse_dates=[0], date_parser=parser, dtype={'Transaction_amount_BTC':'float'})
btctx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380401 entries, 0 to 380400
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   time                    380401 non-null  datetime64[ns]
#  1   Hash                    380401 non-null  object
#  2   Sender                  380401 non-null  object
#  3   Receiver                380401 non-null  object
#  4   Transaction_amount_BTC  380401 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 14.5+ MB

# %%
#combine all rates in one dataframe
path = '/Users/koytoora/JupyterProjects/DataScience/Skillbox/HomeWork/Challenge/btc_usd'
pattern = '*.csv'
glob_path = os.path.join(path, pattern)
list_files = glob.glob(glob_path)
new_file = 'btc_usd.csv'

if list_files:
    with fileinput.FileInput(files=list_files) as fr, open(new_file, 'w') as fw:
        for line in fr:
            if not fr.isfirstline():
                fw.write(line)
            else:
                fw.write(f'\n')

parser = lambda date: datetime.datetime.strptime(date, '%d.%m.%Y')                
btcusd = pd.read_csv('btc_usd.csv', header=None, names=["time","rate"], parse_dates=[0], date_parser=parser)
btcusd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1096 non-null   datetime64[ns]
#  1   rate    1096 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 17.2 KB

# %%
#merge rates and bitcoin transaction to have USD amounts
dataset = btctx.merge(btcusd, how='left', on='time')
dataset['USD'] = dataset.Transaction_amount_BTC * dataset.rate
dataset[dataset.rate == ''].size
#calculate apprx number of senders for each transaction
dataset['sender_lenght'] = [len(i) for i in dataset.Sender]
dataset['senders'] = [int(i) for i in (round(dataset.sender_lenght/34,0))]
dataset['receiver_lenght'] = [len(i) for i in dataset.Receiver]

# %%
#select suspicious bank transfers based on the logic:
#if during a period between begin_date and end_date there was a transfer to ONE bitcoin wallet of equal (+/- 1%) amount of USD
#the more number in Q column - the more probability

mapp['Q'] = ''
for i, row in mapp.iterrows():
    newdataset = dataset[(dataset.time >= row.iloc[3]) & (dataset.time <= row.iloc[4])].groupby('Receiver').agg('sum')['USD'].reset_index()
    newdataset['Diff'] = (newdataset['USD'] - row.iloc[14]) / row.iloc[14]
    newdataset['Trigger'] = [1 if (0.01>=x>-0.01) else 0 for x in newdataset['Diff']]
    mapp.loc[i,'Q'] = sum(newdataset['Trigger'])

# %%
mapp['Q1'] = [1 if x>0 else 0 for x in mapp.Q]
mapp2 = mapp[mapp.Q > 0].sort_values(by="Q", ascending=False)
mapp2
# Out:
#         icij_sar_id                      filer_org_name_id  \
# id
# 230180         3055  fifth-third-bank-national-association
# 227498         3789       the-bank-of-new-york-mellon-corp
# 229512         2208       the-bank-of-new-york-mellon-corp
# 227499         3789       the-bank-of-new-york-mellon-corp
# 229513         2208       the-bank-of-new-york-mellon-corp
# ...             ...                                    ...
# 227505         3789       the-bank-of-new-york-mellon-corp
# 227502         3789       the-bank-of-new-york-mellon-corp
# 235284         3085       the-bank-of-new-york-mellon-corp
# 225887         4076             the-northern-trust-company
# 224101         4262                           barclays-plc
#
#                                 filer_org_name begin_date   end_date  \
# id
# 230180  Fifth Third Bank, National Association 2015-03-18 2016-06-24
# 227498       The Bank of New York Mellon Corp. 2015-12-04 2016-05-11
# 229512       The Bank of New York Mellon Corp. 2015-07-07 2016-03-11
# 227499       The Bank of New York Mellon Corp. 2015-11-02 2016-04-25
# 229513       The Bank of New York Mellon Corp. 2014-07-30 2017-09-21
# ...                                        ...        ...        ...
# 227505       The Bank of New York Mellon Corp. 2016-01-18 2016-03-23
# 227502       The Bank of New York Mellon Corp. 2016-02-24 2016-04-18
# 235284       The Bank of New York Mellon Corp. 2015-12-01 2016-02-01
# 225887              The Northern Trust Company 2015-02-09 2015-03-13
# 224101                            Barclays Plc 2014-07-09 2015-10-05
#
#                                   originator_bank_id  \
# id
# 230180                              fifth-third-bank
# 227498                  united-overseas-bank-limited
# 229512                                  ppf-banka-as
# 227499                                   citibank-na
# 229513  nordea-bank-finland-plc-londonnordea-bank-ab
# ...                                              ...
# 227505                                  dbs-bank-ltd
# 227502                                   citibank-na
# 235284                               bdo-unibank-inc
# 225887                            dms-bank-trust-ltd
# 224101                             baltikums-bank-as
#
#                                       originator_bank originator_bank_country  \
# id
# 230180                               Fifth Third Bank           United States
# 227498                   United Overseas Bank Limited               Singapore
# 229512                                 PPF Banka A.S.          Czech Republic
# 227499                                  Citibank N.A.               Singapore
# 229513  Nordea Bank Finland Plc London/Nordea Bank AB          United Kingdom
# ...                                               ...                     ...
# 227505                                   DBS Bank Ltd               Singapore
# 227502                                  Citibank N.A.               Singapore
# 235284                                Bdo Unibank Inc             Philippines
# 225887                           DMS Bank & Trust Ltd          Cayman Islands
# 224101                              Baltikums Bank AS                  Latvia
#
#        originator_iso                           beneficiary_bank_id  \
# id
# 230180            USA                       fifth-third-bank-us-usa
# 227498            SGP                    dbs-bank-ltd-singapore-sgp
# 229512            CZE  garantibank-international-nv-netherlands-nld
# 227499            SGP    united-overseas-bank-limited-singapore-sgp
# 229513            GBR       efg-private-bank-ltd-london-england-gbr
# ...               ...                                           ...
# 227505            SGP                  hsbc-singapore-singapore-sgp
# 227502            SGP                    dbs-bank-ltd-singapore-sgp
# 235284            PHL                            hsbc-hong-kong-hkg
# 225887            CYM                        banco-itau-uruguay-ury
# 224101            LVA          barclays-bank-plc-nicosia-cyprus-cyp
#
#                       beneficiary_bank beneficiary_bank_country  \
# id
# 230180                Fifth Third Bank            United States
# 227498                    DBS Bank Ltd                Singapore
# 229512  Garantibank International N.V.              Netherlands
# 227499    United Overseas Bank Limited                Singapore
# 229513            EFG Private Bank Ltd           United Kingdom
# ...                                ...                      ...
# 227505                  HSBC Singapore                Singapore
# 227502                    DBS Bank Ltd                Singapore
# 235284                            HSBC                Hong Kong
# 225887                      Banco Itau                  Uruguay
# 224101               Barclays Bank Plc                   Cyprus
#
#        beneficiary_iso  number_transactions  amount_transactions    Q  Q1
# id
# 230180             USA                  8.0           1245000.00  607   1
# 227498             SGP                 13.0           1786929.08  598   1
# 229512             NLD                 16.0           1618000.00  556   1
# 227499             SGP                 14.0           1739599.00  493   1
# 229513             GBR                 12.0           2829522.83  363   1
# ...                ...                  ...                  ...  ...  ..
# 227505             SGP                  4.0           8043761.35    1   1
# 227502             SGP                  9.0          24087154.93    1   1
# 235284             HKG                  7.0           6900000.00    1   1
# 225887             URY                  8.0           1000000.00    1   1
# 224101             CYP                  5.0          13100000.00    1   1
#
# [227 rows x 17 columns]

# %%
fig, ax = plt.subplots(figsize = (20,20))
mapp3 = mapp2.groupby('originator_iso').agg('count')['beneficiary_iso']
plt.pie(mapp3, labels = mapp3.index, autopct='%.0f%%')
plt.show()

# %% [markdown]
# Most of them from Latvia, Russia, Singapore, Cyprus and China

# %%
mapp4 = mapp.groupby('originator_iso').agg({'Q':'count','Q1':'sum'})
mapp4['Rate'] =  mapp4.Q1 / mapp4.Q  * 100
mapp4.sort_values(by='Rate', ascending=False, inplace=True)
fig = plt.figure(figsize = (20,20))
ax = fig.add_subplot()
ax.bar(mapp4[mapp4.Rate>0].index,mapp4[mapp4.Rate>0].Rate, label="Rate")
ax2 = ax.twinx()
ax2.plot(mapp4[mapp4.Rate>0].index,mapp4[mapp4.Rate>0].Q, color='red', label="Transactions")
plt.title( 'Transaction Suspicious rate per country',fontweight = "bold", size=20 )
ax.set_xlabel( "Country" )
ax.set_ylabel( "Rate" )
ax2.set_ylabel( "Total transactions" )
plt.show()
